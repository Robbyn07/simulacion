# %% [markdown]
# ## Práctica Propuesta- SimPy SED
#
# Modifique el código anterior a fin de incorporar los siguientes cambios:
#
# * Considerar 3 tipos de vehículos con 3 diferentes tiempos de lavado:
#     * Bus: 15- 20 minutos
#     * Automóvil: 7-10 minutos
#     * Furgoneta: 12-15 minutos
# * Considere que a partir de la entrada del vehículo para ser lavado, deberán tomarse en cuenta los siguientes tiempos correspondientes al proceso de traslado desde la recepción a la máquina de lavado:
#     * Bus: 4 minutos
#     * Automóvil: 1 minuto
#     * Furgoneta: 2 minutos
# * Identificar el recurso maquina dentro de la simulación
# * Realice una gráfica comparativa de la simulación con 3 y con 4 máquinas de lavado
# * Generar llegada de vehículos de 1 - 2 minutos, por 60 minutos de lavado, el tipo de vehículo es generado aleatoriamente.

# %%
#Se importan las librerias
import simpy
import random
import matplotlib.pyplot as plt

# %%
# Maximo de vehiculos que puede recibir el negocio
MAX_VEHICULOS = 57 
# Total de maquinas de lavado con que cuenta el negocio
NUM_MAQUINAS = 3
# Tiempo de simulación
TIEMPO_SIMULACION = 60 # Cambio de tiempo a 60 mins
# Creamos un diccionario para almacenar las horas en que se lavan los vehiculos
# Esto permite graficar o generar los resultados
tiempo={}
res = []

class Lavanderia(object):
    def __init__(self, environment, num_maquinas):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        
    def lavar_vehiculo(self, vehiculo):
        #Definicion de tiempo de lavado
        if "Bus" in vehiculo: 
            yield self.env.timeout(random.randint(15,20))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        elif "Automóvil" in vehiculo: 
            yield self.env.timeout(random.randint(7,10))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        elif "Furgoneta" in vehiculo: 
            yield self.env.timeout(random.randint(12,15))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))

        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90

def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('En recepcion : %s a la hora %.2f.' % (nombre, env.now))

    if "Bus" in nombre: 
        yield env.timeout(4)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))
    elif "Automóvil" in nombre: 
        yield env.timeout(1)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))
    elif "Furgoneta" in nombre: 
        yield env.timeout(2)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))

    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado
    
    with lavanderia.maquinas.request() as maquina:

        numActual=0
        if str(maquina) in res:
            numActual=  res.index(str(maquina))  
        else: 
            res.append(str(maquina))
            numActual=  res.index(str(maquina)) 

        # Ocupamos la maquina de lavado
        yield maquina
        # Indicamos que vehiculo entra a la lavanderia
        print('Lavándose: %s a la hora %.2f en la Maquina %s.' % (nombre, env.now, numActual+1))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehículo [%s] lavado a las %.2f en la Maquina %s.' % (nombre, env.now, numActual+1))

        # Agregamos al diccionario para obtener los tiempos de lavado
        k=env.now # Permite obtener el tiempo actual de la simulación para generar la clave del diccionario
    
    if k in tiempo:
        tiempo[k]=tiempo[k]+1 # Aumento el numero de autos en el tiempo de salida
    else:
        tiempo[k]=1 # Por defecto empezamos con el primer vehiculo

#Funcion para Generar autos
def generar_auto():
    tipos = ["Bus", "Automóvil", "Furgoneta"]
    num = random.randint(0,2)
    return tipos[num]

def ejecutar_simulacion(env, num_maquinas):
    lavanderia=Lavanderia(env, num_maquinas)
    
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(5):                      
        env.process(llegada_vehiculo(env, str(generar_auto())+'-%d'%(i+1),lavanderia))
    
    # Ejecutamos la simulacion
    while True:                  
        yield env.timeout(random.randint(1, 2))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        env.process(llegada_vehiculo(env,str(generar_auto())+'-%d'%(i+1),lavanderia))

print('Lavanderia UPS')
# Inicializamos la semilla aleatoria
random.seed(77)

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)

print(tiempo)
# Out:
# Lavanderia UPS
# En recepcion : Automóvil-1 a la hora 0.00.
# En recepcion : Automóvil-2 a la hora 0.00.
# En recepcion : Bus-3 a la hora 0.00.
# En recepcion : Bus-4 a la hora 0.00.
# En recepcion : Bus-5 a la hora 0.00.
# En recepcion : Automóvil-6 a la hora 1.00.
# Llega a la máquina de lavado: Automóvil-1 a la hora 1.00.
# Llega a la máquina de lavado: Automóvil-2 a la hora 1.00.
# Lavándose: Automóvil-1 a la hora 1.00 en la Maquina 1.
# Lavándose: Automóvil-2 a la hora 1.00 en la Maquina 2.
# Llega a la máquina de lavado: Automóvil-6 a la hora 2.00.
# Lavándose: Automóvil-6 a la hora 2.00 en la Maquina 3.
# En recepcion : Automóvil-7 a la hora 3.00.
# Llega a la máquina de lavado: Bus-3 a la hora 4.00.
# Llega a la máquina de lavado: Bus-4 a la hora 4.00.
# Llega a la máquina de lavado: Bus-5 a la hora 4.00.
# En recepcion : Automóvil-8 a la hora 4.00.
# Llega a la máquina de lavado: Automóvil-7 a la hora 4.00.
# En recepcion : Bus-9 a la hora 5.00.
# Llega a la máquina de lavado: Automóvil-8 a la hora 5.00.
# En recepcion : Bus-10 a la hora 7.00.
# Removido  {50%} suciedad vehiculo => Automóvil-1
# Removido  {37%} suciedad vehiculo => Automóvil-2
# Removido  {35%} suciedad vehiculo => Automóvil-6
# Llega a la máquina de lavado: Bus-9 a la hora 9.00.
# En recepcion : Furgoneta-11 a la hora 9.00.
# Vehículo [Automóvil-1] lavado a las 9.00 en la Maquina 1.
# Vehículo [Automóvil-2] lavado a las 9.00 en la Maquina 2.
# Vehículo [Automóvil-6] lavado a las 9.00 en la Maquina 3.
# Lavándose: Bus-3 a la hora 9.00 en la Maquina 4.
# Lavándose: Bus-4 a la hora 9.00 en la Maquina 5.
# Lavándose: Bus-5 a la hora 9.00 en la Maquina 6.
# Llega a la máquina de lavado: Bus-10 a la hora 11.00.
# En recepcion : Bus-12 a la hora 11.00.
# Llega a la máquina de lavado: Furgoneta-11 a la hora 11.00.
# En recepcion : Bus-13 a la hora 12.00.
# En recepcion : Bus-14 a la hora 13.00.
# Llega a la máquina de lavado: Bus-12 a la hora 15.00.
# En recepcion : Furgoneta-15 a la hora 15.00.
# Llega a la máquina de lavado: Bus-13 a la hora 16.00.
# En recepcion : Bus-16 a la hora 16.00.
# Llega a la máquina de lavado: Bus-14 a la hora 17.00.
# Llega a la máquina de lavado: Furgoneta-15 a la hora 17.00.
# En recepcion : Furgoneta-17 a la hora 17.00.
# En recepcion : Bus-18 a la hora 19.00.
# Llega a la máquina de lavado: Furgoneta-17 a la hora 19.00.
# Llega a la máquina de lavado: Bus-16 a la hora 20.00.
# En recepcion : Furgoneta-19 a la hora 20.00.
# En recepcion : Bus-20 a la hora 22.00.
# Llega a la máquina de lavado: Furgoneta-19 a la hora 22.00.
# Llega a la máquina de lavado: Bus-18 a la hora 23.00.
# En recepcion : Automóvil-21 a la hora 23.00.
# Llega a la máquina de lavado: Automóvil-21 a la hora 24.00.
# Removido  {70%} suciedad vehiculo => Bus-5
# En recepcion : Furgoneta-22 a la hora 25.00.
# Vehículo [Bus-5] lavado a las 25.00 en la Maquina 6.
# Lavándose: Automóvil-7 a la hora 25.00 en la Maquina 7.
# Llega a la máquina de lavado: Bus-20 a la hora 26.00.
# En recepcion : Furgoneta-23 a la hora 26.00.
# Removido  {83%} suciedad vehiculo => Bus-4
# Llega a la máquina de lavado: Furgoneta-22 a la hora 27.00.
# En recepcion : Automóvil-24 a la hora 27.00.
# Vehículo [Bus-4] lavado a las 27.00 en la Maquina 5.
# Lavándose: Automóvil-8 a la hora 27.00 en la Maquina 8.
# Removido  {66%} suciedad vehiculo => Bus-3
# Llega a la máquina de lavado: Furgoneta-23 a la hora 28.00.
# En recepcion : Automóvil-25 a la hora 28.00.
# Llega a la máquina de lavado: Automóvil-24 a la hora 28.00.
# Vehículo [Bus-3] lavado a las 28.00 en la Maquina 4.
# Lavándose: Bus-9 a la hora 28.00 en la Maquina 9.
# Llega a la máquina de lavado: Automóvil-25 a la hora 29.00.
# En recepcion : Bus-26 a la hora 30.00.
# En recepcion : Bus-27 a la hora 32.00.
# En recepcion : Bus-28 a la hora 33.00.
# Removido  {70%} suciedad vehiculo => Automóvil-7
# Llega a la máquina de lavado: Bus-26 a la hora 34.00.
# Vehículo [Automóvil-7] lavado a las 34.00 en la Maquina 7.
# Lavándose: Bus-10 a la hora 34.00 en la Maquina 2.
# Removido  {77%} suciedad vehiculo => Automóvil-8
# En recepcion : Automóvil-29 a la hora 35.00.
# Vehículo [Automóvil-8] lavado a las 35.00 en la Maquina 8.
# Lavándose: Furgoneta-11 a la hora 35.00 en la Maquina 10.
# Llega a la máquina de lavado: Bus-27 a la hora 36.00.
# Llega a la máquina de lavado: Automóvil-29 a la hora 36.00.
# Llega a la máquina de lavado: Bus-28 a la hora 37.00.
# En recepcion : Automóvil-30 a la hora 37.00.
# Llega a la máquina de lavado: Automóvil-30 a la hora 38.00.
# En recepcion : Bus-31 a la hora 39.00.
# En recepcion : Furgoneta-32 a la hora 41.00.
# En recepcion : Bus-33 a la hora 42.00.
# Llega a la máquina de lavado: Bus-31 a la hora 43.00.
# Llega a la máquina de lavado: Furgoneta-32 a la hora 43.00.
# En recepcion : Furgoneta-34 a la hora 44.00.
# En recepcion : Bus-35 a la hora 45.00.
# Llega a la máquina de lavado: Bus-33 a la hora 46.00.
# Llega a la máquina de lavado: Furgoneta-34 a la hora 46.00.
# Removido  {88%} suciedad vehiculo => Furgoneta-11
# En recepcion : Automóvil-36 a la hora 47.00.
# Vehículo [Furgoneta-11] lavado a las 47.00 en la Maquina 10.
# Lavándose: Bus-12 a la hora 47.00 en la Maquina 1.
# Removido  {30%} suciedad vehiculo => Bus-9
# Llega a la máquina de lavado: Automóvil-36 a la hora 48.00.
# Vehículo [Bus-9] lavado a las 48.00 en la Maquina 9.
# Lavándose: Bus-13 a la hora 48.00 en la Maquina 11.
# Removido  {80%} suciedad vehiculo => Bus-10
# Llega a la máquina de lavado: Bus-35 a la hora 49.00.
# En recepcion : Automóvil-37 a la hora 49.00.
# Vehículo [Bus-10] lavado a las 49.00 en la Maquina 2.
# Lavándose: Bus-14 a la hora 49.00 en la Maquina 12.
# En recepcion : Furgoneta-38 a la hora 50.00.
# Llega a la máquina de lavado: Automóvil-37 a la hora 50.00.
# En recepcion : Bus-39 a la hora 51.00.
# Llega a la máquina de lavado: Furgoneta-38 a la hora 52.00.
# En recepcion : Furgoneta-40 a la hora 52.00.
# En recepcion : Bus-41 a la hora 54.00.
# Llega a la máquina de lavado: Furgoneta-40 a la hora 54.00.
# Llega a la máquina de lavado: Bus-39 a la hora 55.00.
# En recepcion : Automóvil-42 a la hora 56.00.
# En recepcion : Bus-43 a la hora 57.00.
# Llega a la máquina de lavado: Automóvil-42 a la hora 57.00.
# Llega a la máquina de lavado: Bus-41 a la hora 58.00.
# En recepcion : Automóvil-44 a la hora 58.00.
# En recepcion : Bus-45 a la hora 59.00.
# Llega a la máquina de lavado: Automóvil-44 a la hora 59.00.
# {9: 3, 25: 1, 27: 1, 28: 1, 34: 1, 35: 1, 47: 1, 48: 1, 49: 1}

# %%
NUM_MAQUINAS = 4
tiempo2={}

class Lavanderia(object):   
    def __init__(self, environment, num_maquinas):
        # Guardamos como variable el entorno de ejecucion
        self.env=environment
        # Creamos el recurso que representa las maquinas
        self.maquinas = simpy.Resource(environment, num_maquinas)
        
    def lavar_vehiculo(self, vehiculo):
        #Definicion de tiempso de lavado    #Floro
        if "Bus" in vehiculo: 
            yield self.env.timeout(random.randint(15,20))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        elif "Automóvil" in vehiculo: 
            yield self.env.timeout(random.randint(7,10))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))
        elif "Furgoneta" in vehiculo: 
            yield self.env.timeout(random.randint(12,15))
            print('Removido  {%d%%} suciedad vehiculo => %s ' % (random.randint(30,90), vehiculo))

        # Simulamos que se ha limpiado parte (%) de la suciedad del vehiculo
        # Para el % generamos un entero entre 30 y 90
        
def llegada_vehiculo(env, nombre, lavanderia):
    # Usamos el reloj de la simulacion (env.now()) para indicar a la
    # hora que llega el vehiculo con el nombre pasado como parametro
    print('En recepcion : %s a la hora %.2f.' % (nombre, env.now))

    if "Bus" in nombre: 
        yield env.timeout(4)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))
    elif "Automóvil" in nombre: 
        yield env.timeout(1)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))
    elif "Furgoneta" in nombre: 
        yield env.timeout(2)
        print('Llega a la máquina de lavado: %s a la hora %.2f.' % (nombre, env.now))

    # Especificamos que vamos a usar un recurso (Resource) que representa
    # la maquina de lavado

    with lavanderia.maquinas.request() as maquina: 
        numActual=0
        if str(maquina) in res:
            numActual=  res.index(str(maquina))  
        else: 
            res.append(str(maquina))
            numActual=  res.index(str(maquina)) 

        # Ocupamos la maquina de lavado
        yield maquina
        # Indicamos que vehiculo entra a la lavanderia
        print('Lavandose: %s a la hora %.2f en la Maquina %s.' % (nombre, env.now, numActual+1))
        # Procesamos la operacion de lavado
        yield env.process(lavanderia.lavar_vehiculo(nombre))
        # Una vez que termina la llamada con 'yield', se indica que se ha lavado el vehiculo
        print('Vehiculo [%s] lavado a las %.2f en la Maquina %s.' % (nombre, env.now, numActual+1))

        # Agregamos al diccionario para obtener los tiempos de lavado
        k=env.now # Permite obtener el tiempo actual de la simulación para generar la clave del diccionario
    
    if k in tiempo2:
        tiempo2[k]=tiempo2[k]+1 # Aumento el numero de autos en el tiempo de salida
    else:
        tiempo2[k]=1 # Por defecto empezamos con el primer vehiculo

#Funcion para Generar autos
def generar_auto():
    tipos = ["Bus","Automóvil","Furgoneta"]
    num = random.randint(0,2)
    return tipos[num]

def ejecutar_simulacion(env, num_maquinas):
    lavanderia=Lavanderia(env, num_maquinas)
    
    # Creamos 5 llegadas de vehiculos iniciales
    for i in range(5):                      
        env.process(llegada_vehiculo(env, str(generar_auto())+'-%d'%(i+1),lavanderia))
    
    # Ejecutamos la simulacion
    while True:                  
        yield env.timeout(random.randint(1, 2))
        i+=1
        # Mientras se lavan los vehiculos generamos mas vehiculos
        env.process(llegada_vehiculo(env,str(generar_auto())+'-%d'%(i+1),lavanderia))

print('Lavanderia UPS')
# Inicializamos la semilla aleatoria
random.seed(77)

# Creamos el entorno de simulacion
env=simpy.Environment()
env.process(ejecutar_simulacion(env, NUM_MAQUINAS))

# Ejecutamos el proceso durante el tiempo de simulacion
env.run(until = TIEMPO_SIMULACION)

print(tiempo2)
# Out:
# Lavanderia UPS
# En recepcion : Automóvil-1 a la hora 0.00.
# En recepcion : Automóvil-2 a la hora 0.00.
# En recepcion : Bus-3 a la hora 0.00.
# En recepcion : Bus-4 a la hora 0.00.
# En recepcion : Bus-5 a la hora 0.00.
# En recepcion : Automóvil-6 a la hora 1.00.
# Llega a la máquina de lavado: Automóvil-1 a la hora 1.00.
# Llega a la máquina de lavado: Automóvil-2 a la hora 1.00.
# Lavandose: Automóvil-1 a la hora 1.00 en la Maquina 41.
# Lavandose: Automóvil-2 a la hora 1.00 en la Maquina 42.
# Llega a la máquina de lavado: Automóvil-6 a la hora 2.00.
# Lavandose: Automóvil-6 a la hora 2.00 en la Maquina 43.
# En recepcion : Automóvil-7 a la hora 3.00.
# Llega a la máquina de lavado: Bus-3 a la hora 4.00.
# Llega a la máquina de lavado: Bus-4 a la hora 4.00.
# Llega a la máquina de lavado: Bus-5 a la hora 4.00.
# En recepcion : Automóvil-8 a la hora 4.00.
# Llega a la máquina de lavado: Automóvil-7 a la hora 4.00.
# Lavandose: Bus-3 a la hora 4.00 en la Maquina 44.
# En recepcion : Furgoneta-9 a la hora 5.00.
# Llega a la máquina de lavado: Automóvil-8 a la hora 5.00.
# En recepcion : Bus-10 a la hora 7.00.
# Llega a la máquina de lavado: Furgoneta-9 a la hora 7.00.
# Removido  {50%} suciedad vehiculo => Automóvil-1
# Removido  {37%} suciedad vehiculo => Automóvil-2
# Removido  {35%} suciedad vehiculo => Automóvil-6
# En recepcion : Furgoneta-11 a la hora 9.00.
# Vehiculo [Automóvil-1] lavado a las 9.00 en la Maquina 41.
# Vehiculo [Automóvil-2] lavado a las 9.00 en la Maquina 42.
# Vehiculo [Automóvil-6] lavado a las 9.00 en la Maquina 43.
# Lavandose: Bus-4 a la hora 9.00 en la Maquina 45.
# Lavandose: Bus-5 a la hora 9.00 en la Maquina 46.
# Lavandose: Automóvil-7 a la hora 9.00 en la Maquina 47.
# Llega a la máquina de lavado: Bus-10 a la hora 11.00.
# En recepcion : Bus-12 a la hora 11.00.
# Llega a la máquina de lavado: Furgoneta-11 a la hora 11.00.
# En recepcion : Bus-13 a la hora 12.00.
# En recepcion : Bus-14 a la hora 13.00.
# Llega a la máquina de lavado: Bus-12 a la hora 15.00.
# En recepcion : Furgoneta-15 a la hora 15.00.
# Llega a la máquina de lavado: Bus-13 a la hora 16.00.
# En recepcion : Bus-16 a la hora 16.00.
# Removido  {77%} suciedad vehiculo => Automóvil-7
# Llega a la máquina de lavado: Bus-14 a la hora 17.00.
# Llega a la máquina de lavado: Furgoneta-15 a la hora 17.00.
# En recepcion : Automóvil-17 a la hora 17.00.
# Vehiculo [Automóvil-7] lavado a las 17.00 en la Maquina 47.
# Lavandose: Automóvil-8 a la hora 17.00 en la Maquina 48.
# En recepcion : Furgoneta-18 a la hora 18.00.
# Llega a la máquina de lavado: Automóvil-17 a la hora 18.00.
# Removido  {82%} suciedad vehiculo => Bus-3
# Llega a la máquina de lavado: Bus-16 a la hora 20.00.
# En recepcion : Bus-19 a la hora 20.00.
# Llega a la máquina de lavado: Furgoneta-18 a la hora 20.00.
# Vehiculo [Bus-3] lavado a las 20.00 en la Maquina 44.
# Lavandose: Furgoneta-9 a la hora 20.00 en la Maquina 49.
# En recepcion : Automóvil-20 a la hora 21.00.
# En recepcion : Automóvil-21 a la hora 22.00.
# Llega a la máquina de lavado: Automóvil-20 a la hora 22.00.
# En recepcion : Automóvil-22 a la hora 23.00.
# Llega a la máquina de lavado: Automóvil-21 a la hora 23.00.
# Removido  {44%} suciedad vehiculo => Automóvil-8
# Llega a la máquina de lavado: Bus-19 a la hora 24.00.
# En recepcion : Furgoneta-23 a la hora 24.00.
# Llega a la máquina de lavado: Automóvil-22 a la hora 24.00.
# Vehiculo [Automóvil-8] lavado a las 24.00 en la Maquina 48.
# Lavandose: Bus-10 a la hora 24.00 en la Maquina 50.
# En recepcion : Furgoneta-24 a la hora 26.00.
# Llega a la máquina de lavado: Furgoneta-23 a la hora 26.00.
# Removido  {79%} suciedad vehiculo => Bus-5
# En recepcion : Automóvil-25 a la hora 27.00.
# Vehiculo [Bus-5] lavado a las 27.00 en la Maquina 46.
# Lavandose: Furgoneta-11 a la hora 27.00 en la Maquina 51.
# Removido  {33%} suciedad vehiculo => Bus-4
# Llega a la máquina de lavado: Furgoneta-24 a la hora 28.00.
# En recepcion : Automóvil-26 a la hora 28.00.
# Llega a la máquina de lavado: Automóvil-25 a la hora 28.00.
# Vehiculo [Bus-4] lavado a las 28.00 en la Maquina 45.
# Lavandose: Bus-12 a la hora 28.00 en la Maquina 41.
# En recepcion : Automóvil-27 a la hora 29.00.
# Llega a la máquina de lavado: Automóvil-26 a la hora 29.00.
# Llega a la máquina de lavado: Automóvil-27 a la hora 30.00.
# En recepcion : Bus-28 a la hora 31.00.
# En recepcion : Furgoneta-29 a la hora 33.00.
# Removido  {33%} suciedad vehiculo => Furgoneta-9
# Vehiculo [Furgoneta-9] lavado a las 34.00 en la Maquina 49.
# Lavandose: Bus-13 a la hora 34.00 en la Maquina 52.
# Llega a la máquina de lavado: Bus-28 a la hora 35.00.
# En recepcion : Automóvil-30 a la hora 35.00.
# Llega a la máquina de lavado: Furgoneta-29 a la hora 35.00.
# En recepcion : Bus-31 a la hora 36.00.
# Llega a la máquina de lavado: Automóvil-30 a la hora 36.00.
# En recepcion : Furgoneta-32 a la hora 38.00.
# Removido  {31%} suciedad vehiculo => Furgoneta-11
# En recepcion : Automóvil-33 a la hora 39.00.
# Vehiculo [Furgoneta-11] lavado a las 39.00 en la Maquina 51.
# Lavandose: Bus-14 a la hora 39.00 en la Maquina 53.
# Llega a la máquina de lavado: Bus-31 a la hora 40.00.
# Llega a la máquina de lavado: Furgoneta-32 a la hora 40.00.
# Llega a la máquina de lavado: Automóvil-33 a la hora 40.00.
# En recepcion : Furgoneta-34 a la hora 41.00.
# Removido  {33%} suciedad vehiculo => Bus-10
# En recepcion : Automóvil-35 a la hora 42.00.
# Vehiculo [Bus-10] lavado a las 42.00 en la Maquina 50.
# Lavandose: Furgoneta-15 a la hora 42.00 en la Maquina 54.
# Llega a la máquina de lavado: Furgoneta-34 a la hora 43.00.
# En recepcion : Furgoneta-36 a la hora 43.00.
# Llega a la máquina de lavado: Automóvil-35 a la hora 43.00.
# En recepcion : Bus-37 a la hora 44.00.
# Llega a la máquina de lavado: Furgoneta-36 a la hora 45.00.
# En recepcion : Furgoneta-38 a la hora 45.00.
# En recepcion : Bus-39 a la hora 47.00.
# Llega a la máquina de lavado: Furgoneta-38 a la hora 47.00.
# Removido  {60%} suciedad vehiculo => Bus-12
# Llega a la máquina de lavado: Bus-37 a la hora 48.00.
# Vehiculo [Bus-12] lavado a las 48.00 en la Maquina 41.
# Lavandose: Automóvil-17 a la hora 48.00 en la Maquina 47.
# En recepcion : Bus-40 a la hora 49.00.
# En recepcion : Automóvil-41 a la hora 50.00.
# Llega a la máquina de lavado: Bus-39 a la hora 51.00.
# En recepcion : Bus-42 a la hora 51.00.
# Llega a la máquina de lavado: Automóvil-41 a la hora 51.00.
# En recepcion : Bus-43 a la hora 52.00.
# Llega a la máquina de lavado: Bus-40 a la hora 53.00.
# En recepcion : Bus-44 a la hora 53.00.
# Removido  {85%} suciedad vehiculo => Bus-13
# Removido  {44%} suciedad vehiculo => Furgoneta-15
# En recepcion : Furgoneta-45 a la hora 54.00.
# Vehiculo [Bus-13] lavado a las 54.00 en la Maquina 52.
# Vehiculo [Furgoneta-15] lavado a las 54.00 en la Maquina 54.
# Lavandose: Bus-16 a la hora 54.00 en la Maquina 55.
# Lavandose: Furgoneta-18 a la hora 54.00 en la Maquina 56.
# Removido  {61%} suciedad vehiculo => Automóvil-17
# Llega a la máquina de lavado: Bus-42 a la hora 55.00.
# Vehiculo [Automóvil-17] lavado a las 55.00 en la Maquina 47.
# Lavandose: Automóvil-20 a la hora 55.00 en la Maquina 57.
# Llega a la máquina de lavado: Bus-43 a la hora 56.00.
# En recepcion : Furgoneta-46 a la hora 56.00.
# Llega a la máquina de lavado: Furgoneta-45 a la hora 56.00.
# Removido  {60%} suciedad vehiculo => Bus-14
# Llega a la máquina de lavado: Bus-44 a la hora 57.00.
# En recepcion : Furgoneta-47 a la hora 57.00.
# Vehiculo [Bus-14] lavado a las 57.00 en la Maquina 53.
# Lavandose: Automóvil-21 a la hora 57.00 en la Maquina 58.
# Llega a la máquina de lavado: Furgoneta-46 a la hora 58.00.
# En recepcion : Furgoneta-48 a la hora 59.00.
# Llega a la máquina de lavado: Furgoneta-47 a la hora 59.00.
# {9: 3, 17: 1, 20: 1, 24: 1, 27: 1, 28: 1, 34: 1, 39: 1, 42: 1, 48: 1, 54: 2, 55: 1, 57: 1}

# %%
etiqueta = list(tiempo.keys())
valores = list(tiempo.values())
plt.bar(range(len(tiempo)), valores, align="center", tick_label=etiqueta)
plt.title("Tiempo/Salida Vehículos con 3 Maquinas")
plt.xlabel("Tiempo")
plt.ylabel("Nro. Vehículos")
plt.show()

etiqueta = list(tiempo2.keys())
valores = list(tiempo2.values())
plt.bar(range(len(tiempo2)), valores, align="center", tick_label=etiqueta)
plt.title("Tiempo/Salida Vehículos con 4 Maquinas")
plt.xlabel("Tiempo")
plt.ylabel("Nro. Vehículos")
plt.show()
